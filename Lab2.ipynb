# %%
! pip install -q hvplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import hvplot.pandas

# %matplotlib inline
# %env HV_DOC_HTML=true
# Out:
# env: HV_DOC_HTML=true

# %%
diamonds_data = sns.load_dataset('diamonds')

# %% [markdown]
# ## Загальна інформація про датасет

# %%
diamonds_data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamonds_data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
missing_values = diamonds_data.isna().sum()
print("Columns with missing values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with missing values:
# Series([], dtype: int64)

# %% [markdown]
# ## Всі унікальні значення категоріальних стовбчиків

# %%
diamonds_data.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
diamonds_data.clarity.unique()
# Out:
# ['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF']
# Categories (8, object): ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
diamonds_data.color.unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %% [markdown]
# ## Підготовка даних

# %%
diamonds_data_encoded = diamonds_data
diamonds_data_encoded['cut_labels'] = diamonds_data['cut'].map({'Fair': 1, 'Good': 2, 'Very Good': 3, 'Premium': 4, 'Ideal': 5})
diamonds_data_encoded['cut_labels'] = diamonds_data_encoded['cut_labels'].astype(int)
diamonds_data_encoded.drop(columns=['cut'], inplace=True)

# %%
diamonds_data_encoded = pd.get_dummies(diamonds_data_encoded, columns=['clarity'])

# %%
diamonds_data_encoded = pd.get_dummies(diamonds_data_encoded, columns=['color'])

# %%
diamonds_data_encoded.head()
# Out:
#    carat  depth  table  price     x     y     z  cut_labels  clarity_IF  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43           5       False
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31           4       False
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31           2       False
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63           4       False
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75           2       False
#
#    clarity_VVS1  ...  clarity_SI1  clarity_SI2  clarity_I1  color_D  color_E  \
# 0         False  ...        False         True       False    False     True
# 1         False  ...         True        False       False    False     True
# 2         False  ...        False        False       False    False     True
# 3         False  ...        False        False       False    False    False
# 4         False  ...        False         True       False    False    False
#
#    color_F  color_G  color_H  color_I  color_J
# ...

# %%
diamonds_data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carat         53940 non-null  float64
#  1   depth         53940 non-null  float64
#  2   table         53940 non-null  float64
#  3   price         53940 non-null  int64
#  4   x             53940 non-null  float64
#  5   y             53940 non-null  float64
#  6   z             53940 non-null  float64
#  7   cut_labels    53940 non-null  int64
#  8   clarity_IF    53940 non-null  bool
#  9   clarity_VVS1  53940 non-null  bool
#  10  clarity_VVS2  53940 non-null  bool
#  11  clarity_VS1   53940 non-null  bool
#  12  clarity_VS2   53940 non-null  bool
#  13  clarity_SI1   53940 non-null  bool
#  14  clarity_SI2   53940 non-null  bool
#  15  clarity_I1    53940 non-null  bool
#  16  color_D       53940 non-null  bool
#  17  color_E       53940 non-null  bool
# ...

# %% [markdown]
# ## Візуалізація числових ознак

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.hist('price', bins=50, title='Розподіл price', color='blue')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1802'>
#   <div id="c2e06b6d-ee26-4973-83d8-b737a6008c6d" data-root-id="p1802" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.hist('carat', bins=50, title='Розподіл carat', color='yellow')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1870'>
#   <div id="eb75cb42-22e7-41fe-8258-b1726bbaf85a" data-root-id="p1870" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.hist('depth', bins=50, title='Розподіл depth', color='purple')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1938'>
#   <div id="bf3e9efc-5e06-4f13-8232-27f1c38da83a" data-root-id="p1938" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.hist('table', bins=30, title='Розподіл table', color='green')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p2006'>
#   <div id="c5b10cf2-77c1-4484-a687-d4f76f5c0187" data-root-id="p2006" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.scatter(x='carat', y='price', title='Взаємозв’язок між carat та price', color='red')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p2074'>
#   <div id="f8bedbd2-107c-4eeb-9284-0d5dadbf7bc6" data-root-id="p2074" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.scatter(x='depth', y='price', title='Взаємозв’язок між depth та price', color='pink')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p2139'>
#   <div id="bb72f90d-eae9-42a7-b89d-03a841a56f33" data-root-id="p2139" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
hvplot.extension('bokeh')
diamonds_data.hvplot.scatter(x='table', y='price', title='Взаємозв’язок між table та price', color='brown')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p2204'>
#   <div id="f428a917-4736-4537-9f87-04431e318461" data-root-id="p2204" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## Кореляційний аналіз

# %%
hvplot.extension('bokeh')
correlation_matrix = diamonds_data_encoded.corr()
heatmap = correlation_matrix.hvplot.heatmap(title='Кореляційна матриця', cmap='coolwarm', rot=45)
heatmap
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p2269'>
#   <div id="a31ff78b-53d2-4110-a3b1-7b635435cd90" data-root-id="p2269" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## Навчання моделей

# %%
X = diamonds_data_encoded.drop(columns='price') # ознаки
y = diamonds_data_encoded['price'] # ціни

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scalar', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %% [markdown]
# ### Функції для оцінки моделей

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
def cross_val(model):
    pred = cross_val_score(model, X_train, y_train, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')

def evaluate(true, predicted):
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return rmse, r2_square

# %% [markdown]
# ### Лінійна регресія

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression() # задаємо модель
lin_reg.fit(X_train, y_train) # навчаємо
# Out:
# LinearRegression()

# %%
lin_reg.intercept_
# Out:
# 3951.495312251709

# %%
coeff_df = pd.DataFrame(lin_reg.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#               Coefficient
# carat         5346.493066
# depth         -109.525716
# table          -60.640645
# x            -1129.932357
# y                9.347332
# z              -30.393427
# cut_labels     116.125474
# clarity_IF     242.464994
# clarity_VVS1   254.110056
# clarity_VVS2   272.066892
# clarity_VS1    203.134223
# clarity_VS2    103.385429
# clarity_SI1   -143.919410
# clarity_SI2   -492.196436
# clarity_I1    -485.756320
# color_D        210.603330
# color_E        163.591174
# color_F        139.025944
# color_G         55.623129
# color_H       -130.588368
# color_I       -250.448316
# color_J       -386.974299

# %%
test_pred = lin_reg.predict(X_test)
train_pred = lin_reg.predict(X_train)

print('Test set evaluation:\n__________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n__________________________________')
print_evaluate(y_train, train_pred)

results_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y_test, test_pred) , cross_val(LinearRegression())]],
                          columns=['Model', 'RMSE', 'R2 Square', "Cross Validation"])
# Out:
# Test set evaluation:
# __________________________________
# RMSE: 1118.2983830447365
# R2 Square 0.9198131436385688
# __________________________________
# Train set evaluation:
# __________________________________
# RMSE: 1139.289842433365
# R2 Square 0.9191341409973967
# __________________________________

# %% [markdown]
# ### Ridge регресія

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=100, solver='cholesky', tol=0.0001, random_state=42)
ridge_model.fit(X_train, y_train)
pred = ridge_model.predict(X_test)

test_pred = ridge_model.predict(X_test)
train_pred = ridge_model.predict(X_train)

print('Test set evaluation:\n__________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n__________________________________')
print_evaluate(y_train, train_pred)

results_df_2 = pd.DataFrame(data=[["Ridge Regression", *evaluate(y_test, test_pred) , cross_val(Ridge())]],
                          columns=['Model', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = pd.concat([results_df, results_df_2], ignore_index=True)
# Out:
# Test set evaluation:
# __________________________________
# RMSE: 1121.2866728540876
# R2 Square 0.9193840243179761
# __________________________________
# Train set evaluation:
# __________________________________
# RMSE: 1141.5973287809713
# R2 Square 0.9188062422963608
# __________________________________

# %% [markdown]
# ### LASSO регресія

# %%
from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=0.1,
              precompute=True,
              positive=True,
              selection='random',
              random_state=42)
lasso_model.fit(X_train, y_train)

test_pred = lasso_model.predict(X_test)
train_pred = lasso_model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)

results_df_2 = pd.DataFrame(data=[["Lasso Regression", *evaluate(y_test, test_pred) , cross_val(Lasso())]],
                            columns=['Model', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = pd.concat([results_df, results_df_2], ignore_index=True)
# Out:
# Test set evaluation:
# _____________________________________
# RMSE: 1147.5351320575971
# R2 Square 0.9155655313385227
# __________________________________
# Train set evaluation:
# _____________________________________
# RMSE: 1166.2815001394094
# R2 Square 0.915257059976919
# __________________________________

# %% [markdown]
# ### Elastic Net

# %%
from sklearn.linear_model import ElasticNet

elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.9, selection='random', random_state=42)
elastic_model.fit(X_train, y_train)

test_pred = elastic_model.predict(X_test)
train_pred = elastic_model.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)

results_df_2 = pd.DataFrame(data=[["Elastic Net Regression", *evaluate(y_test, test_pred) , cross_val(ElasticNet())]],
                            columns=['Model', 'RMSE', 'R2 Square', "Cross Validation"])
results_df = pd.concat([results_df, results_df_2], ignore_index=True)
# Out:
# Test set evaluation:
# _____________________________________
# RMSE: 1139.8203117732435
# R2 Square 0.9166970123359918
# __________________________________
# Train set evaluation:
# _____________________________________
# RMSE: 1159.1656621014283
# R2 Square 0.9162879902297835
# __________________________________

# %% [markdown]
# ### Поліноміальна регресія

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=2)

X_train_2_d = poly_reg.fit_transform(X_train)
X_test_2_d = poly_reg.transform(X_test)

lin_reg = LinearRegression()
lin_reg.fit(X_train_2_d,y_train)

test_pred = lin_reg.predict(X_test_2_d)
train_pred = lin_reg.predict(X_train_2_d)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)

results_df_2 = pd.DataFrame(data=[["Polynomail Regression", *evaluate(y_test, test_pred), 0]],
                            columns=['Model', 'RMSE', 'R2 Square', 'Cross Validation'])
results_df = pd.concat([results_df, results_df_2], ignore_index=True)
# Out:
# Test set evaluation:
# _____________________________________
# RMSE: 1476.7529782327754
# R2 Square 0.8601689867557926
# __________________________________
# Train set evaluation:
# _____________________________________
# RMSE: 675.9190376473728
# R2 Square 0.9715366435827651
# __________________________________

# %%
results_df
# Out:
#                     Model         RMSE  R2 Square  Cross Validation
# 0       Linear Regression  1118.298383   0.919813          0.917703
# 1        Ridge Regression  1121.286673   0.919384          0.917763
# 2        Lasso Regression  1147.535132   0.915566          0.918808
# 3  Elastic Net Regression  1139.820312   0.916697          0.841831
# 4   Polynomail Regression  1476.752978   0.860169          0.000000
